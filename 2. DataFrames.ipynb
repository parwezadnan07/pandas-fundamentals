# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Creating a Data Frame

# %%
data = {'Names' :['John', 'Anna', 'Peter', 'Linda'],
         'Age': [28, 34, 29, 42],
         'City': ['New York', 'Paris', 'Berlin', 'London'],
         'Salary': [65000, 70000, 62000, 85000] }
df = pd.DataFrame(data)
df
# Out:
#    Names  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
list = [
         ['John', 28, 'New York', 65000],
         ['Anna', 34, 'Paris', 70000],
         ['Peter', 29, 'Berlin', 62000],
         ['Linda', 42, 'London', 85000]
]

list1 = ['Name', 'Age', 'City', 'Salary']
df1 = pd.DataFrame(list, columns = list1)
df1
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# Selection and Indexing of Columns

# %%
df1
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df1['Name']
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: Name, dtype: str

# %%
df1[['Name', 'City']]
# Out:
#     Name      City
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %% [markdown]
# Creating a new Column

# %%
df1['Designation'] = ['Doctor', 'Engineer', 'Physiotherepist', 'Coder']
df1
# Out:
#     Name  Age      City  Salary      Designation
# 0   John   28  New York   65000           Doctor
# 1   Anna   34     Paris   70000         Engineer
# 2  Peter   29    Berlin   62000  Physiotherepist
# 3  Linda   42    London   85000            Coder

# %% [markdown]
# Removing Column(s)

# %%
df1.drop("Designation", axis = 1)
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df1
# Out:
#     Name  Age      City  Salary      Designation
# 0   John   28  New York   65000           Doctor
# 1   Anna   34     Paris   70000         Engineer
# 2  Peter   29    Berlin   62000  Physiotherepist
# 3  Linda   42    London   85000            Coder

# %%
df1.drop(['Age', 'City'], axis = 1)
# Out:
#     Name  Salary      Designation
# 0   John   65000           Doctor
# 1   Anna   70000         Engineer
# 2  Peter   62000  Physiotherepist
# 3  Linda   85000            Coder

# %% [markdown]
# Removing row(s)

# %%
df1.drop(0, axis = 0)
# Out:
#     Name  Age    City  Salary      Designation
# 1   Anna   34   Paris   70000         Engineer
# 2  Peter   29  Berlin   62000  Physiotherepist
# 3  Linda   42  London   85000            Coder

# %% [markdown]
# Selecting Row(s)

# %%
df1
# Out:
#     Name  Age      City  Salary      Designation
# 0   John   28  New York   65000           Doctor
# 1   Anna   34     Paris   70000         Engineer
# 2  Peter   29    Berlin   62000  Physiotherepist
# 3  Linda   42    London   85000            Coder

# %%
df1.loc[0]
# Out:
# Name               John
# Age                  28
# City           New York
# Salary            65000
# Designation      Doctor
# Name: 0, dtype: object

# %%
df1.loc[[0,1]]
# Out:
#    Name  Age      City  Salary Designation
# 0  John   28  New York   65000      Doctor
# 1  Anna   34     Paris   70000    Engineer

# %%
df1.iloc[3]
# Out:
# Name            Linda
# Age                42
# City           London
# Salary          85000
# Designation     Coder
# Name: 3, dtype: object

# %% [markdown]
# Selecting Subsets of Rows and Columns

# %%
df1
# Out:
#     Name  Age      City  Salary      Designation
# 0   John   28  New York   65000           Doctor
# 1   Anna   34     Paris   70000         Engineer
# 2  Peter   29    Berlin   62000  Physiotherepist
# 3  Linda   42    London   85000            Coder

# %%
df1.loc[[0,1]][['Salary', 'Designation']]
# Out:
#    Salary Designation
# 0   65000      Doctor
# 1   70000    Engineer

# %%
df1.loc[[2,3]][['Name', 'Age']]
# Out:
#     Name  Age
# 2  Peter   29
# 3  Linda   42

# %% [markdown]
# Conditional Selection

# %%
df1
# Out:
#     Name  Age      City  Salary      Designation
# 0   John   28  New York   65000           Doctor
# 1   Anna   34     Paris   70000         Engineer
# 2  Peter   29    Berlin   62000  Physiotherepist
# 3  Linda   42    London   85000            Coder

# %%
# I only want to see those people whosw age is greater than 30

# %%
df1[df1['Age'] > 30]
# Out:
#     Name  Age    City  Salary Designation
# 1   Anna   34   Paris   70000    Engineer
# 3  Linda   42  London   85000       Coder

# %%
# I only want to see those people whose age is greater than 30 and salary is greater than 650000

# %%
df1[(df1['Age'] > 30) & (df1['Salary'] > 65000)]
# Out:
#     Name  Age    City  Salary Designation
# 1   Anna   34   Paris   70000    Engineer
# 3  Linda   42  London   85000       Coder
